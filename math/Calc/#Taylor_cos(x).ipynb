# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as pl
from functools import reduce

# %%
def fact(x):
    test = lambda x: x*x
    return reduce(lambda x,y: x*y, range(1,x+1))

# %%
x = np.arange(-5,5,0.1)
y = np.cos(x)
print(*range(1,5))
# Out:
# 1 2 3 4

# %%
ty0 = 1 + 0*x
ty1 = 1 + 0*x
ty2 = 1 + 0*x + -1/(fact(2))*x**2

# %%
fig, ax = pl.subplots()

pl.plot(x,y)
pl.plot(x,ty2)
