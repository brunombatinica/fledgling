# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#PS 8, I

x = np.linspace(0,2,100)
y = np.log(np.tan(x)) / ( np.sin(x) - np.cos(x))

fig, ax = plt.subplots()
ax.plot(x,y)
ax.axvline((np.pi)/4)
ax.axhline(np.sqrt(2))
#ax.axhline(0)
# Out:
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17240/3641004538.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(np.tan(x)) / ( np.sin(x) - np.cos(x))
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17240/3641004538.py:4: RuntimeWarning: invalid value encountered in log
#   y = np.log(np.tan(x)) / ( np.sin(x) - np.cos(x))
