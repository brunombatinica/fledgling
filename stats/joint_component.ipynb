# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.random.normal(5,1,10)
b = a + np.random.normal(0,0.5,10)
c = a + np.random.normal(0,1.5,10)

# %%
plt.scatter(a,b)

# %%
plt.scatter(a,c)

# %%
# covariance patter

# covariance between each pair of regions

np.corrcoef(np.array([a,b,c]))
# Out:
# array([[1.        , 0.92571644, 0.59997625],
#        [0.92571644, 1.        , 0.68754583],
#        [0.59997625, 0.68754583, 1.        ]])

# %%
# identify the eigenvectors and eigenvalues
