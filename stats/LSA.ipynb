# %% [markdown]
# # Learning LSA Latent Semantic Analysis - NEED TO DO LINKED TUTORIAL IT IS GOOD!
#
# Going off https://www.datacamp.com/tutorial/discovering-hidden-topics-python

# %% [markdown]
# Technique in Topic modelling
#
# ![image.png](attachment:image.png)

# %% [markdown]
# TOPIC MODELLING vs TEXT CLASSIFICATION
#
# - Text classification in supervised
# - Topic modelling is hte process of deiscovering groups of co-occuring words in text documents
#     These group co-occuring related words make "topics"
#     Unsupervised

# %% [markdown]
# # LSA
#
# LSA uses a bag of words model - which results in a term document matrix
#     Each row is a words
#     Each column is a document
#
#     Each entry is how many times that word appears in that matrix

# %%
# SVD - See SVD notebook
